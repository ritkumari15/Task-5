# %% [markdown]
# # Task#5
#
# ## Perform 'exploratory data analysis' on the provided dataset "samplesuperstore'.
#
# ###  you are the business owner of the retail firm and want to see how your company is performing. you are interested in finding out the weak areas where you can work to make profit. what all business problems you can derive by looking into the data? you can choose any of the tool of your choice(Python/R/Tableau/PowerBI/Excel).
#
# ### Dataset:-https://drive.google.com/file/d/1lV7is1B566UQPYzzY8R2ZmoritTW299S/edit

# %%
#Import all necessary Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#import Data
df=pd.read_csv(r'D:\spark\SampleSuperstore.csv')
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.duplicated().sum()
# Out:
# 17

# %%
df.drop_duplicates(keep='first',inplace=True)
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9977 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9977 non-null   object
#  1   Segment       9977 non-null   object
#  2   Country       9977 non-null   object
#  3   City          9977 non-null   object
#  4   State         9977 non-null   object
#  5   Postal Code   9977 non-null   int64
#  6   Region        9977 non-null   object
#  7   Category      9977 non-null   object
#  8   Sub-Category  9977 non-null   object
#  9   Sales         9977 non-null   float64
#  10  Quantity      9977 non-null   int64
#  11  Discount      9977 non-null   float64
#  12  Profit        9977 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount      Profit
# count   9977.000000   9977.000000  9977.000000  9977.000000  9977.00000
# mean   55154.964117    230.148902     3.790719     0.156278    28.69013
# std    32058.266816    623.721409     2.226657     0.206455   234.45784
# min     1040.000000      0.444000     1.000000     0.000000 -6599.97800
# 25%    23223.000000     17.300000     2.000000     0.000000     1.72620
# 50%    55901.000000     54.816000     3.000000     0.200000     8.67100
# 75%    90008.000000    209.970000     5.000000     0.200000    29.37200
# max    99301.000000  22638.480000    14.000000     0.800000  8399.97600

# %%
#Deleting the Variable.
col=['Postal Code']
sample1=df.drop(columns=col,axis=1)

# %%
#Correlation Between Variables.
sample1.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200722 -0.028311  0.479067
# Quantity  0.200722  1.000000  0.008678  0.066211
# Discount -0.028311  0.008678  1.000000 -0.219662
# Profit    0.479067  0.066211 -0.219662  1.000000

# %%
df.iloc[10]
# Out:
# Ship Mode       Standard Class
# Segment               Consumer
# Country          United States
# City               Los Angeles
# State               California
# Postal Code              90032
# Region                    West
# Category             Furniture
# Sub-Category            Tables
# Sales                  1706.18
# Quantity                     9
# Discount                   0.2
# Profit                 85.3092
# Name: 10, dtype: object

# %% [markdown]
# # Data Visualization

# %%
sample1.hist(bins=50 ,figsize=(20,15))
plt.show();

# %%
df.mean()
# Out:
# Postal Code    55154.964117
# Sales            230.148902
# Quantity           3.790719
# Discount           0.156278
# Profit            28.690130
# dtype: float64

# %%
sns.heatmap(df.corr(),annot=True)

# %%
sns.distplot(df['Sales'], color= 'orange')
plt.xlim(-300,5000)
plt.show()

# %%
sns.distplot(df['Quantity'], color= 'green')
plt.show()

# %%
sns.distplot(df['Discount'], color= 'orange')
plt.show()

# %%
sns.distplot(df['Profit'], color= 'green')
plt.xlim(-4000,4000)
plt.show()

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# ### The stores are located in USA only.

# %%
# The business details are about USA only.
df['Country'].value_counts()
# Out:
# United States    9977
# Name: Country, dtype: int64

# %% [markdown]
# ## State wise analysis of Number of Sales(According to transaction records)

# %%
df1 = df['State'].value_counts()
df1
# Out:
# California              1996
# New York                1127
# Texas                    983
# Pennsylvania             586
# Washington               502
# Illinois                 491
# Ohio                     468
# Florida                  383
# Michigan                 254
# North Carolina           249
# Virginia                 224
# Arizona                  224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
df['State'].value_counts().plot(kind='bar', figsize= (20,10))
plt.ylabel('Frequency / Number of deals')
plt.xlabel('States')
plt.show()

# %% [markdown]
# ## The state with maximum number of dealings is Califirnia and Wyomming with minimum

# %%
df['State'].value_counts().mean()
# Out:
# 203.6122448979592

# %% [markdown]
# ## Average number of deals per state are near to 204

# %%
df1[df1 < df['State'].value_counts().mean()].index
# Out:
# Index(['Georgia', 'Tennessee', 'Colorado', 'Indiana', 'Kentucky',
#        'Massachusetts', 'New Jersey', 'Oregon', 'Wisconsin', 'Maryland',
#        'Delaware', 'Minnesota', 'Connecticut', 'Missouri', 'Oklahoma',
#        'Alabama', 'Arkansas', 'Rhode Island', 'Utah', 'Mississippi',
#        'South Carolina', 'Louisiana', 'Nevada', 'Nebraska', 'New Mexico',
#        'Iowa', 'New Hampshire', 'Kansas', 'Idaho', 'Montana', 'South Dakota',
#        'Vermont', 'District of Columbia', 'Maine', 'North Dakota',
#        'West Virginia', 'Wyoming'],
#       dtype='object')

# %% [markdown]
# ### There are many states with no of deals less than the average Number of Deals. They need to work on their reach to customers and promote better to gain attention. As For profit the no of deals mmust increase.
#
# ## Number of Sales City wise

# %%
df2 = df['City'].value_counts()
df2
# Out:
# New York City    914
# Los Angeles      746
# Philadelphia     536
# San Francisco    506
# Seattle          424
#                 ...
# Conway             1
# Kissimmee          1
# Cheyenne           1
# Margate            1
# Littleton          1
# Name: City, Length: 531, dtype: int64

# %%
 #Plotting the Number of Deals in Cities (Top 100)
df['City'].value_counts().head(100).plot(kind='bar', figsize= (20,10), color= 'orange')
plt.ylabel('Frequency / Number of deals')
plt.xlabel('Cities')
plt.show()

# %%
df['City'].value_counts().mean()
# Out:
# 18.789077212806028

# %%
df2[df2 < df['City'].value_counts().mean()].index # Cities with no of deals less than the average.
# Out:
# Index(['Chesapeake', 'Hialeah', 'Roswell', 'Westminster', 'Tallahassee',
#        'Cincinnati', 'North Las Vegas', 'Alexandria', 'Redlands',
#        'Virginia Beach',
#        ...
#        'Grand Island', 'Whittier', 'Ormond Beach', 'Rock Hill', 'Yucaipa',
#        'Conway', 'Kissimmee', 'Cheyenne', 'Margate', 'Littleton'],
#       dtype='object', length=442)

# %%
citynames = list(df2[df2 == 1].index.values)
df2[df2 == 1]
# Out:
# Elyria         1
# Manhattan      1
# Billings       1
# Lindenhurst    1
# La Quinta      1
#               ..
# Conway         1
# Kissimmee      1
# Cheyenne       1
# Margate        1
# Littleton      1
# Name: City, Length: 70, dtype: int64

# %% [markdown]
# ### There are near about 70 cities with number of deals equal to one only. They need to work on their performance for atracting the customers
#
# ### Analysing Cities with less performance

# %%
df3 = df.set_index('City').loc[citynames]
df3 = df3[['Quantity', 'Segment', 'Category', 'Sub-Category']]
sns.countplot(df3['Category'])
#plt.xlabel('Categories')
plt.show()

# %%
sns.countplot(df3['Sub-Category'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### Seeing the above plots we can deduce most of the low performance cities are near to offices and corporate life, low residential areas. Hence only office requirements are bought maximum.
#
# #### At such places we can improve the commotion in stores by setting up a small cafe or something, where the corporates can take a break and chill. This can get their attention.

# %%
sns.countplot(df3['Segment'])
plt.show()

# %%
df.corr().plot.bar();

# %%
# Percentage of Quantities of Items bought
plt.figure(figsize=(8,8))
plt.pie(df3['Quantity'].value_counts(),labels=list(df3['Quantity'].value_counts().index),autopct='%1.1f%%')
plt.title('Percentage of Quantities of Items bought')
plt.legend()
plt.show()

# %% [markdown]
# ## State wise Sales, Profit and Discount analysis¶

# %%
df1 = df.groupby(['State'])[['Sales', 'Discount','Profit']].mean()
df1
# Out:
#                             Sales  Discount      Profit
# State
# Alabama                319.846557  0.000000   94.865989
# Arizona                157.508933  0.303571  -15.303235
# Arkansas               194.635500  0.000000   66.811452
# California             229.246629  0.072946   38.241878
# Colorado               176.418231  0.316484  -35.867351
# Connecticut            163.223866  0.007317   42.823071
# Delaware               285.948635  0.006250  103.930988
# District of Columbia   286.502000  0.000000  105.958930
# Florida                233.612815  0.299347   -8.875461
# Georgia                266.825217  0.000000   88.315453
# Idaho                  208.689810  0.085714   39.367767
# Illinois               163.263823  0.389206  -25.665275
# Indiana                359.431946  0.000000  123.375411
# Iowa                   152.658667  0.000000   39.460397
# Kansas                 121.429583  0.000000   34.851813
# Kentucky               263.250000  0.000000   80.573357
# ...

# %%
df2 =  df['State'].value_counts().to_frame()
df1 = pd.merge(df1, df2, left_index=True, right_index=True)
df1
# Out:
#                             Sales  Discount      Profit  State
# Alabama                319.846557  0.000000   94.865989     61
# Arizona                157.508933  0.303571  -15.303235    224
# Arkansas               194.635500  0.000000   66.811452     60
# California             229.246629  0.072946   38.241878   1996
# Colorado               176.418231  0.316484  -35.867351    182
# Connecticut            163.223866  0.007317   42.823071     82
# Delaware               285.948635  0.006250  103.930988     96
# District of Columbia   286.502000  0.000000  105.958930     10
# Florida                233.612815  0.299347   -8.875461    383
# Georgia                266.825217  0.000000   88.315453    184
# Idaho                  208.689810  0.085714   39.367767     21
# Illinois               163.263823  0.389206  -25.665275    491
# Indiana                359.431946  0.000000  123.375411    149
# Iowa                   152.658667  0.000000   39.460397     30
# ...

# %%
df1.rename(columns={'State':'NoOfDeals'},inplace = True)

# %%
plt.figure(figsize = (20,14))
sns.violinplot(data = df, x='State', y= 'Sales',palette='muted')
#plt.ylim(-1000,2300)
plt.xticks(rotation = 90)
plt.ylabel('Average Sales in Dollars')
plt.xlabel('States')
plt.show()

# %%
df1.sort_values('Profit')[['NoOfDeals','Sales','Profit']].plot(kind='bar', figsize= (20,10),label=['NoOfDeals','Avg Sales Price($)','Profit($)'])
plt.ylabel('No Of Deals/Average Sales Price($) and Profit per State($)')
plt.xlabel('States')
plt.legend()
plt.show()

# %%
# Sorted on basis of Discount
df1.sort_values('Profit')[['Discount','Profit']].plot(kind='bar', figsize= (20,10))
plt.ylabel('Discount($) and Profit($) per State')
plt.xlabel('States')
plt.legend()
plt.show()

# %% [markdown]
# ## City wise Sales analysis

# %%
df1 = df.groupby(['City'])[['Sales', 'Discount','Profit']].mean()
df1
# Out:
#                   Sales  Discount      Profit
# City
# Aberdeen      25.500000  0.000000    6.630000
# Abilene        1.392000  0.800000   -3.758400
# Akron        129.999333  0.357143   -8.887410
# Albuquerque  158.582857  0.057143   45.292007
# Alexandria   344.973125  0.000000   19.913644
# ...                 ...       ...         ...
# Woonsocket    48.887500  0.000000   19.669775
# Yonkers      510.511067  0.066667  184.517047
# York         163.595600  0.420000  -20.433840
# Yucaipa       50.800000  0.000000   13.208000
# Yuma         210.216250  0.450000 -116.497725
#
# [531 rows x 3 columns]

# %%
df2 =  df['City'].value_counts().to_frame()
df1 = pd.merge(df1, df2, left_index=True, right_index=True)
df1
# Out:
#                   Sales  Discount      Profit  City
# Aberdeen      25.500000  0.000000    6.630000     1
# Abilene        1.392000  0.800000   -3.758400     1
# Akron        129.999333  0.357143   -8.887410    21
# Albuquerque  158.582857  0.057143   45.292007    14
# Alexandria   344.973125  0.000000   19.913644    16
# ...                 ...       ...         ...   ...
# Woonsocket    48.887500  0.000000   19.669775     4
# Yonkers      510.511067  0.066667  184.517047    15
# York         163.595600  0.420000  -20.433840     5
# Yucaipa       50.800000  0.000000   13.208000     1
# Yuma         210.216250  0.450000 -116.497725     4
#
# [531 rows x 4 columns]

# %%
df1.rename(columns={'City':'NoOfDeals'},inplace = True)
# Sorted on basis of Profit in Dollars. Plotted the 50 Cities with Best Sales
df1.sort_values('Profit').tail(50)[['NoOfDeals','Sales','Profit']].plot(kind='bar',figsize= (20,10),label=['NoOfDeals','Avg Sales Price($)','Profit($)'])
plt.ylabel('No Of Deals/Average Sales Price($) and Profit per City($)')
plt.xlabel('Cities')
plt.legend()
plt.show()

# %%
# Sorted on basis of Profit in Dollars. Plotted the 50 Cities with least Sales
df1.sort_values('Profit').head(50)[['NoOfDeals','Sales','Profit']].plot(kind='bar',figsize= (20,10),label=['NoOfDeals','Avg Sales Price($)','Profit($)'])
plt.ylabel('No Of Deals/Average Sales Price($) and Profit per City($)')
plt.xlabel('Cities')
plt.legend()
plt.show()

# %%
# Sorted on basis of Profit.Plotted the 50 Cities with Best Profit
df1.sort_values('Profit')[['Discount','Profit']].tail(50).plot(kind='bar', figsize= (20,10))
plt.ylabel('Discount($) and Profit($) per City')
plt.xlabel('Cities')
plt.legend()
plt.show()

# %%
# Sorted on basis of Profit.Plotted the 50 Cities with Least Profit
df1.sort_values('Profit')[['Discount','Profit']].head(50).plot(kind='bar', figsize= (20,10))
plt.ylabel('Discount($) and Profit($) per City')
plt.xlabel('Cities')
plt.legend()
plt.show()

# %% [markdown]
# ## We can see we can get maximum profit in Jamestown City and minimum in Bethlehem.
#
# ##### In Jamestown No of Deals is very less still Sales in Dollars and Profit is much more. This indicates the quality of the deals is too good. (Maybe the expensive goods are bought more at Vermont)
# #### In Bethlehem Profit is negative and loss is maximum.

# %%
sns.distplot(df1['Discount'])

# %%
df1[df1.Discount == df1['Discount'].max()]
# Out:
#                Sales  Discount   Profit  NoOfDeals
# Abilene        1.392       0.8  -3.7584          1
# Deer Park      6.924       0.8 -10.3860          1
# Missouri City  6.370       0.8  -9.5550          1
# Romeoville     8.952       0.8 -14.7708          1

# %% [markdown]
# ## Overall analysis of Goods and their categories in all the stores

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64

# %%
df['Category'].value_counts().plot(kind = 'bar', color= 'purple')
plt.xlabel('Category')
plt.ylabel('Count')
plt.figure(figsize=(6,6))
plt.pie(df['Category'].value_counts(),labels=df['Category'].value_counts().index,autopct='%1.1f%%')
plt.title('Percentage of Diff Categories of Items bought')
plt.legend()
plt.show()

# %% [markdown]
# # Categorical Variables

# %%
categorical_features=[feature for feature in df.columns if df[feature].dtypes=='O']
print('number of categorical features:-',len(categorical_features))
# Out:
# number of categorical features:- 8

# %%
# Plot the relationship between sales and profit
plt.scatter(x=df['Sales'],y=df['Profit'])
plt.xlabel("Total Sales")
plt.ylabel("Profit")
plt.show()

# %%
sns.set_style('ticks')
sns.countplot(x='Region',data=df,palette='hls')

# %%
sns.set(style="whitegrid")
plt.figure(2, figsize=(20,15))

sns.barplot(x='Sub-Category',y='Profit', data=df, palette='Spectral')

plt.suptitle('Pie Consumption Patterns in the United States', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Pie Consumption Patterns in the United States')

# %%
figsize=(15,10)
sns.pairplot(sample1,hue='Sub-Category')

# %% [markdown]
# ## Using Cluster Analysis(K-Mean Clustering)

# %%
x = df.iloc[:, [9, 10, 11, 12]].values
from sklearn.cluster import KMeans
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
sns.set_style("whitegrid") 
sns.FacetGrid(df, hue ="Sub-Category",height = 6).map(plt.scatter,'Sales','Quantity')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'yellow', label = 'Centroids')

plt.legend()

# %%
sns.set_style("whitegrid") 
sns.FacetGrid(df, hue ="Sub-Category",height = 6).map(plt.scatter,'Sales','Profit')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'yellow', label = 'Centroids')

plt.legend()

# %% [markdown]
# ### Now we Grouped or sum the sales ,profit,discount,quantity according to every state of region and also according to sub-categories sales.

# %%
grouped=pd.DataFrame(df.groupby(['Ship Mode','Segment','Category','Sub-Category','State','Region'])['Quantity','Discount','Sales','Profit'].sum().reset_index())
grouped
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#            Ship Mode      Segment    Category Sub-Category       State  \
# 0        First Class     Consumer   Furniture    Bookcases     Arizona
# 1        First Class     Consumer   Furniture    Bookcases  California
# 2        First Class     Consumer   Furniture    Bookcases    Colorado
# 3        First Class     Consumer   Furniture    Bookcases     Florida
# 4        First Class     Consumer   Furniture    Bookcases     Georgia
# ...              ...          ...         ...          ...         ...
# 2978  Standard Class  Home Office  Technology       Phones       Texas
# 2979  Standard Class  Home Office  Technology       Phones     Vermont
# 2980  Standard Class  Home Office  Technology       Phones    Virginia
# ...

# %%
### sum,mean,min,max,count median,standard deviation,Variance of each states of Profit
df.groupby("State").Profit.agg(["sum","mean","min","max","count","median","std","var"])
# Out:
#                              sum        mean        min        max  count  \
# State
# Alabama                5786.8253   94.865989     0.0000  1459.2000     61
# Arizona               -3427.9246  -15.303235  -814.4832   211.4955    224
# Arkansas               4008.6871   66.811452     1.4190   843.1706     60
# California            76330.7891   38.241878  -325.5720  1906.4850   1996
# Colorado              -6527.8579  -35.867351 -3399.9800   247.9960    182
# Connecticut            3511.4918   42.823071   -15.5826   294.6710     82
# Delaware               9977.3748  103.930988   -48.7839  5039.9856     96
# District of Columbia   1059.5893  105.958930     4.4344   648.5624     10
# Florida               -3399.3017   -8.875461 -1811.0784   327.5922    383
# Georgia               16250.0433   88.315453     0.1134  3177.4750    184
# Idaho                   826.7231   39.367767     1.1151   259.5297     21
# Illinois             -12601.6500  -25.665275 -2929.4845   874.9875    491
# ...

# %%
df['Sub-Category'].value_counts().plot(kind = 'bar', color= 'orange')
plt.xlabel('Sub-Categories')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Office Supplies are sold maximum from the stores. So the quality of such goods must be nice. Whereas the Technology items are sold minimum so the store must include better quality techy items where the crowd requires.

# %%
df['Region'].value_counts().plot(kind = 'bar', color= 'orange')
plt.xlabel('Regions')
plt.ylabel('Count')
plt.figure(figsize=(6,6))
plt.pie(df['Region'].value_counts(),labels=df['Region'].value_counts().index,autopct='%1.1f%%')
plt.title('Percentage of Deals happened diff Regions of USA')
plt.legend()
plt.show()

# %% [markdown]
# #### We can see maximum deals occur in West Region, whereas minimum in South. Hence Stores i West USA are performing better and other stores need to improve
